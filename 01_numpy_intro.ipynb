# %% [markdown]
# <a href="https://colab.research.google.com/github/krzysztof-ui/data-sceince-bootcamp/blob/main/01_numpy_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
np.__version__
# Out:
# '2.1.3'

# %%
print(dir(np))

# %%
help(np.array)

# %%
x = np.array([1,3])
print(x)
# Out:
# [1 3]

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x.ndim   # Wymiar tablicy
# Out:
# 1

# %%
x.shape  # Kształt tablicy
# Out:
# (2,)

# %%
x.size # liczba elementów w tablicy
# Out:
# 2

# %%
x.dtype # typ danych w tablicy
# Out:
# dtype('int64')

# %%
x = np.array([1.3, 2.3, 1.4])
print(x)
# Out:
# [1.3 2.3 1.4]

# %%
x.dtype
# Out:
# dtype('float64')

# %%
x = np.array([[1, 2], [-3, 1]])
x
# Out:
# array([[ 1,  2],
#        [-3,  1]])

# %%
x.ndim
# Out:
# 2

# %%
x.shape
# Out:
# (2, 2)

# %%
x = np.array([[1, 2, 4], [4, 2, 1]])
print(x)
# Out:
# [[1 2 4]
#  [4 2 1]]

# %%
x.shape
# Out:
# (2, 3)

# %%
x = np.array(
    [[[4, 3, 1],
      [3, 1, 2]],

     [[4, 1, 3],
      [4, 2, 1]],

     [[3, 2, 1],
      [4, 3, 2]]]

)

x
# Out:
# array([[[4, 3, 1],
#         [3, 1, 2]],
#
#        [[4, 1, 3],
#         [4, 2, 1]],
#
#        [[3, 2, 1],
#         [4, 3, 2]]])

# %%
x.ndim
# Out:
# 3

# %%
x.shape
# Out:
# (3, 2, 3)

# %%
A = np.array([1, 2, 3])
A.dtype
# Out:
# dtype('int64')

# %%
A = np.array([1.0, 2.3, 3,3])
A.dtype
# Out:
# dtype('float64')

# %%
A = np.array([1, 2, 3], dtype='float')
A.dtype
# Out:
# dtype('float64')

# %%
A = np.array([1, 2, 3], dtype='complex')
A.dtype
# Out:
# dtype('complex128')

# %%
A = np.array([1.0, 2.7, 3.3], dtype='int')
A.dtype
# Out:
# dtype('int64')

# %%
A
# Out:
# array([1, 2, 3])

# %%
A = np.array([True, False])
A.dtype
# Out:
# dtype('bool')

# %%
A = np.array([24, 120, 125], dtype=np.int8)
A.dtype
# Out:
# dtype('int8')

# %%
A = np.array([24, 120, 125], dtype=np.uint8)
A.dtype
# Out:
# dtype('uint8')
